# %%
# !pip install numpy-stl
# Out:
# Collecting numpy-stl
#   Downloading numpy-stl-2.11.2.tar.gz (484 kB)
#      |████████████████████████████████| 484 kB 450 kB/s eta 0:00:01
# Requirement already satisfied: numpy in /home/zhanz0j/.local/lib/python3.6/site-packages (from numpy-stl) (1.18.1)
# Collecting python-utils>=1.6.2
#   Downloading python_utils-2.4.0-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: six in /home/zhanz0j/.local/lib/python3.6/site-packages (from python-utils>=1.6.2->numpy-stl) (1.14.0)
# Building wheels for collected packages: numpy-stl
#   Building wheel for numpy-stl (setup.py) ... done
#   Created wheel for numpy-stl: filename=numpy_stl-2.11.2-cp36-cp36m-linux_x86_64.whl size=137767 sha256=22b8710a37a372be34302095ed375aedb1d99db309c2ff84c0f8e5d97fee2c8a
#   Stored in directory: /home/zhanz0j/.cache/pip/wheels/d9/40/2c/feeb8255b8c2cfcbe9a791fa5cb7036d07fdde6fd65557f108
# Successfully built numpy-stl
# Installing collected packages: python-utils, numpy-stl
# Successfully installed numpy-stl-2.11.2 python-utils-2.4.0

# %%
from matplotlib import pyplot as plt
from mpl_toolkits import mplot3d
# %matplotlib inline

# %%
from stl import mesh
# Out:
# /home/zhanz0j/anaconda3/envs/deepchem/lib/python3.6/importlib/_bootstrap.py:219: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   return f(*args, **kwds)

# %%
figure = plt.figure()
axes = mplot3d.Axes3D(figure)

# %%
my_mesh = mesh.Mesh.from_file('BASE_AsianLantern2.stl')
axes.add_collection3d(mplot3d.art3d.Poly3DCollection(my_mesh.vectors))

# %%
scale = my_mesh.points.flatten()
axes.auto_scale_xyz(scale, scale, scale)

# %%
plt.show()

# %%
figure
